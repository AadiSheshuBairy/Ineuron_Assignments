# %%
#1. Add the current date to the text file today.txt as a string.

import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 22-05-2023

# %%
#2. Read the text file today.txt into the string today_string

file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 22-05-2023

# %%
#3. Parse the date from today_string.

from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-05-22 00:00:00

# %%
#4. List the files in your current directory

import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)

# %%
#5. Create a list of all of the files in your parent directory (minimum five files should be available).

import os 
os.listdir()
# Out:
# ['.anaconda',
#  '.astropy',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.git',
#  '.gitconfig',
#  '.gnupg',
#  '.idea',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.pylint.d',
#  '.vscode',
#  'aadi.py',
#  'abc.zip',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'archive (1).zip',
#  'Assignment1..ipynb',
#  'Assignment2.ipynb',
#  'assignment2.py',
#  'Assignment3.ipynb',
#  'Assignment4.ipynb',
#  'Assignment5.ipynb',
#  'Assignment_10.ipynb',
#  'Assignment_11.ipynb',
#  'Assignment_12.ipynb',
#  'Assignment_13.ipynb',
#  'Assignment_14.ipynb',
#  'Assignment_15.ipynb',
#  'Assignment_16.ipynb',
#  'Assignment_17.ipynb',
#  'Assignment_18.ipynb',
#  'Assignment_19.ipynb',
#  'Assignment_20.ipynb',
#  'Assignment_21.ipynb',
#  'Assignment_6.ipynb',
#  'Assignment_7.ipynb',
#  'Assignment_8.ipynb',
#  'Assignment_9.ipynb',
#  'books.csv',
#  'books.db',
#  'challenge1',
#  'Challenge1.ipynb',
#  'check.txt',
#  'Contacts',
#  'Cookies',
#  'corona.data.py.ipynb',
#  'corona_info_data.csv',
#  'datatype.py',
#  'datetime_modle.ipynb',
#  'day3task4.py.ipynb',
#  'day3task6.py.ipynb',
#  'day4listpractice.py.ipynb',
#  'decisiontree.py',
#  'demo.txt',
#  'Documents',
#  'Downloads',
#  'EDA with Automation Tool.ipynb',
#  'eda.ipynb',
#  'EDA_Algerian_Forest_Fire_Dataset.ipynb',
#  'EDA_using_Automation_tools.ipynb',
#  'EDA_Zomato_Dataset.ipynb',
#  'exception handling.ipynb',
#  'Favorites',
#  'file handling .txt.ipynb',
#  'file_handling',
#  'file_handling.py.ipynb',
#  'FinalReport.html',
#  'functions.ipynb',
#  'HelloWorld.py',
#  'IMdb_movies_data.csv',
#  'ineiuronDay5.ipynb',
#  'KNN_Classifier.py.ipynb',
#  'Linear,Ridge,Lasso,&Elestic_Regression_Algerian_Forest_Dataset.ipynb',
#  'Linear-Regression-Ridge-Lasso-Elastic-Net.jpg',
#  'LinearRegression_salaryDataset.py.ipynb',
#  'linear_regression.py.ipynb',
#  'Links',
#  'LIve_class_EDA.ipynb',
#  'Local Settings',
#  'logistic regression.ipynb',
#  'Microsoft',
#  'mini project on super market bill generation.ipynb',
#  'multiple elements replacing using replace().py.ipynb',
#  'Music',
#  'My Documents',
#  'myself.py.ipynb',
#  'mysql1',
#  'NetHood',
#  'New folder',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{04b0a005-46b4-11ed-a545-b9c21831d877}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{04b0a005-46b4-11ed-a545-b9c21831d877}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{04b0a005-46b4-11ed-a545-b9c21831d877}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{04b0a005-46b4-11ed-a545-b9c21831d877}.TxR.blf',
#  'NTUSER.DAT{04b0a006-46b4-11ed-a545-b9c21831d877}.TM.blf',
#  'NTUSER.DAT{04b0a006-46b4-11ed-a545-b9c21831d877}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{04b0a006-46b4-11ed-a545-b9c21831d877}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'number guessing.ipynb',
#  'number_gusseing task27 .ipynb',
#  'OneDrive',
#  'oops_bike.ipynb',
#  'outliers.py.ipynb',
#  'pandas.ineuron.ipynb',
#  'pandas_day2.ipynb',
#  'pandas_ineuron.ipynb',
#  'patterns.py.ipynb',
#  'Pictures',
#  'Postman',
#  'practice-Copy1.task2.py',
#  'practice-Copy2.task2.py',
#  'practice-Copy3.task2.py',
#  'practice.py',
#  'practice.task2.py',
#  'practice.txt',
#  'Practise.ipynb',
#  'PrintHood',
#  'Programming_Assignment1.ipynb',
#  'Programming_Assignment2.ipynb',
#  'Programming_Assignment3.ipynb',
#  'Programming_Assignment4.ipynb',
#  'Programming_Assignment5.ipynb',
#  'PycharmProjects',
#  'python feb1',
#  'python.txt',
#  'python.txt.ipynb',
#  'python.xlsx',
#  'python.xlsx.ipynb',
#  'python1.py',
#  'Recent',
#  'Saved Games',
#  'scrap.py.ipynb',
#  'ScStore',
#  'Searches',
#  'SendTo',
#  'spam.ipynb',
#  'Start Menu',
#  'SVM.ipynb',
#  'Task1.ineuron.ipynb',
#  'task10stringspractice.py.ipynb',
#  'task14 dict practice.ipynb',
#  'task15tuple practice.ipynb',
#  'task16sets practice.ipynb',
#  'task17functions practice.ipynb',
#  'task18ATM using functions.ipynb',
#  'task19.csv,xl,docx.ipynb',
#  'Task1_String.txt',
#  'task2.ineuron.ipynb',
#  'task2.py.ipynb',
#  'Task2.txt',
#  'task20filehandling,practice.ipynb',
#  'task22.exeception_handling_practice.ipynb',
#  'task30_tital_oops_practice.ipynb',
#  'task35_practice_all_adv_func.ipynb',
#  'task37.ipynb',
#  'task38,39,40.ipynb',
#  'Task3_conditional_statements.txt',
#  'Task3_Ineuron.ipynb',
#  'task4 operators&conditional statements.ipynb',
#  'task41numpy.py.ipynb',
#  'task43pandas_notebook.py.ipynb',
#  'task44_matplotlib_notebook.ipynb',
#  'task45_EDA.ipynb',
#  'Task4_function.ipynb',
#  'task6for,while,pass,break,continue.py.ipynb',
#  'Task6_mysql_mongo_db.ipynb',
#  'task6_sql.ipynb',
#  'Task7_pandas.ipynb',
#  'Templates',
#  'test.json',
#  'test.py.ipynb',
#  'test.txt',
#  'test1.py.ipynb',
#  'test_task',
#  'text.txt',
#  'Thyroid_Disease_Prediction.ipynb',
#  'today.txt',
#  'untitled',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled100.ipynb',
#  'Untitled101.ipynb',
#  'Untitled102.ipynb',
#  'Untitled103.ipynb',
#  'Untitled104.ipynb',
#  'Untitled105.ipynb',
#  'Untitled106.ipynb',
#  'Untitled107.ipynb',
#  'Untitled108.ipynb',
#  'Untitled109.ipynb',
#  'Untitled11.ipynb',
#  'Untitled110.ipynb',
#  'Untitled111.ipynb',
#  'Untitled112.ipynb',
#  'Untitled113.ipynb',
#  'Untitled114.ipynb',
#  'Untitled115.ipynb',
#  'Untitled116.ipynb',
#  'Untitled117.ipynb',
#  'Untitled118.ipynb',
#  'Untitled119.ipynb',
#  'Untitled12.ipynb',
#  'Untitled120.ipynb',
#  'Untitled121.ipynb',
#  'Untitled122.ipynb',
#  'Untitled123.ipynb',
#  'Untitled124.ipynb',
#  'Untitled125.ipynb',
#  'Untitled126.ipynb',
#  'Untitled127.ipynb',
#  'Untitled128.ipynb',
#  'Untitled129.ipynb',
#  'Untitled13.ipynb',
#  'Untitled130.ipynb',
#  'Untitled131.ipynb',
#  'Untitled132.ipynb',
#  'Untitled133.ipynb',
#  'Untitled134.ipynb',
#  'Untitled135.ipynb',
#  'Untitled136.ipynb',
#  'Untitled137.ipynb',
#  'Untitled138.ipynb',
#  'Untitled139.ipynb',
#  'Untitled14.ipynb',
#  'Untitled140.ipynb',
#  'Untitled141.ipynb',
#  'Untitled142.ipynb',
#  'Untitled143.ipynb',
#  'Untitled144.ipynb',
#  'Untitled145.ipynb',
#  'Untitled146.ipynb',
#  'Untitled147.ipynb',
#  'Untitled147.py.ipynb',
#  'Untitled148.ipynb',
#  'Untitled148.py.ipynb',
#  'Untitled149.ipynb',
#  'Untitled15.ipynb',
#  'Untitled150.ipynb',
#  'Untitled151.ipynb',
#  'Untitled152.ipynb',
#  'Untitled153.ipynb',
#  'Untitled154.ipynb',
#  'Untitled155.ipynb',
#  'Untitled156.ipynb',
#  'Untitled157.ipynb',
#  'Untitled158.ipynb',
#  'Untitled159.ipynb',
#  'Untitled16.ipynb',
#  'Untitled160.ipynb',
#  'Untitled161.ipynb',
#  'Untitled162.ipynb',
#  'Untitled163.ipynb',
#  'Untitled164.ipynb',
#  'Untitled165.ipynb',
#  'Untitled166.ipynb',
#  'Untitled167.ipynb',
#  'Untitled168.ipynb',
#  'Untitled169.ipynb',
#  'Untitled17.ipynb',
#  'Untitled170.ipynb',
#  'Untitled171.ipynb',
#  'Untitled172.ipynb',
#  'Untitled173.ipynb',
#  'Untitled174.ipynb',
#  'Untitled175.ipynb',
#  'Untitled176.ipynb',
#  'Untitled177.ipynb',
#  'Untitled178.ipynb',
#  'Untitled179.ipynb',
#  'Untitled18.ipynb',
#  'Untitled18.py.ipynb',
#  'Untitled180.ipynb',
#  'Untitled181.ipynb',
#  'Untitled182.ipynb',
#  'Untitled183.ipynb',
#  'Untitled184.ipynb',
#  'Untitled185.ipynb',
#  'Untitled186.ipynb',
#  'Untitled187.ipynb',
#  'Untitled188.ipynb',
#  'Untitled189.ipynb',
#  'Untitled19.ipynb',
#  'Untitled190.ipynb',
#  'Untitled191.ipynb',
#  'Untitled192.ipynb',
#  'Untitled193.ipynb',
#  'Untitled194.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled45.ipynb',
#  'Untitled46.ipynb',
#  'Untitled47.ipynb',
#  'Untitled48.ipynb',
#  'Untitled49.ipynb',
#  'Untitled5.ipynb',
#  'Untitled50.ipynb',
#  'Untitled51.ipynb',
#  'Untitled52.ipynb',
#  'Untitled53.ipynb',
#  'Untitled54.ipynb',
#  'Untitled55.ipynb',
#  'Untitled56.ipynb',
#  'Untitled57.ipynb',
#  'Untitled58.ipynb',
#  'Untitled59.ipynb',
#  'Untitled6.ipynb',
#  'Untitled60.ipynb',
#  'Untitled61.ipynb',
#  'Untitled62.ipynb',
#  'Untitled63.ipynb',
#  'Untitled64.ipynb',
#  'Untitled65.ipynb',
#  'Untitled66.ipynb',
#  'Untitled67.ipynb',
#  'Untitled68.ipynb',
#  'Untitled69.ipynb',
#  'Untitled7.ipynb',
#  'Untitled70.ipynb',
#  'Untitled71.ipynb',
#  'Untitled72.ipynb',
#  'Untitled73.ipynb',
#  'Untitled74.ipynb',
#  'Untitled75.ipynb',
#  'Untitled76.ipynb',
#  'Untitled77.ipynb',
#  'Untitled78.ipynb',
#  'Untitled79.ipynb',
#  'Untitled8.ipynb',
#  'Untitled80.ipynb',
#  'Untitled81.ipynb',
#  'Untitled82.ipynb',
#  'Untitled83.ipynb',
#  'Untitled84.ipynb',
#  'Untitled85.ipynb',
#  'Untitled86.ipynb',
#  'Untitled87.ipynb',
#  'Untitled88.ipynb',
#  'Untitled89.ipynb',
#  'Untitled9.ipynb',
#  'Untitled90.ipynb',
#  'Untitled91.ipynb',
#  'Untitled92.ipynb',
#  'Untitled93.ipynb',
#  'Untitled94.ipynb',
#  'Untitled95.ipynb',
#  'Untitled96.ipynb',
#  'Untitled97.ipynb',
#  'Untitled98.ipynb',
#  'Untitled99.ipynb',
#  'using_forloop_in_file_handling&exception_handling.ipynb',
#  'Videos',
#  'yt.py.ipynb',
#  '_netrc',
#  '__pycache__']

# %%
'''6. Use multiprocessing to create three separate processes. 
Make each one wait a random number of seconds between one and five, print the current time, and then exit.'''

import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %%
#7. Create a date object of your day of birth.

from datetime import datetime
my_dob = datetime.strptime('09/04/2000','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2000-04-09 00:00:00 <class 'datetime.datetime'>

# %%
8. What day of the week was your day of birth?
from datetime import datetime
my_dob = datetime(1997,4,22)
my_dob.strftime("%A")
# Out:
# Object `birth` not found.
# 'Tuesday'

# %%
9. When will you be (or when were you) 10,000 days old?
from datetime import datetime, timedelta
my_dob = datetime.strptime("09/04/2000",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# Object `old` not found.
# datetime.datetime(1972, 11, 22, 0, 0)
